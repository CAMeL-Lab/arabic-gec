# %%
import json
import copy
from collections import defaultdict
import difflib
import re

# %%
def load_data(path):
    src_tokens = []
    tgt_tokens = []
    tags = []
    examples = []

    with open(path, mode='r') as f:
        for line in f.readlines()[1:]:
            line = line.split('\t')
            if len(line) == 3:
                src, tgt, tag = line
                src_tokens.append(src)
                tgt_tokens.append(tgt)
                tags.append(tag.strip())
            else:
                examples.append((src_tokens, tgt_tokens, tags))
                src_tokens = []
                tgt_tokens = []
                tags = []

        if src and tgt and tags:
            examples.append((src_tokens, tgt_tokens, tags))

    return examples

# %%
tricky_set = set()

class CorruptFactory:
    def __init__(self, model, counts, examples):
        self.model = model
        self.counts = counts
        self.examples = examples
    
    @classmethod
    def build(cls, data):
        model = defaultdict(lambda: defaultdict(lambda: 0))
        examples = defaultdict(lambda: defaultdict(lambda: list()))
        
        counts = dict()
        
    
        for example in data:
            src_tokens, tgt_tokens, areta_tags = example
            assert len(src_tokens) == len(tgt_tokens) == len(areta_tags)
            
            for i in range(len(src_tokens)):
                tgt_t, src_t, tag = tgt_tokens[i], src_tokens[i], areta_tags[i]
            
                if tag != 'UC' and tag != 'UNK':
                    if '+' not in tag:
                        replace_rules = create_rule(tgt_t, src_t, tag)
                        if replace_rules:
                            for x in replace_rules:
                                model[(x['pattern'], tag)][x['rule']] += 1
                                examples[(x['pattern'], tag)][x['rule']].append({'src': tgt_t, 'tgt': src_t})
                                counts[(x['pattern'], tag)] = 1 + counts.get((x['pattern'], tag), 0)
                                
                                
        
        
        for pattern, tag in model:
            for rule in model[(pattern, tag)]:
                model[(pattern, tag)][rule] /= float(counts[(pattern, tag)])
        

        return cls(model, counts, examples)

    def __len__(self):
        return len(self.model)
    
    def __getitem__(self, tt_tag):

        tgt_t, tag = tt_tag
        
        if (tgt_t, tag) in self.model:
            return dict(self.model[tgt_t, tag])
        
        return None
    
def create_rule(orig, corr, areta_tag, negative_indices=True):
    sm = difflib.SequenceMatcher(None,
                             orig,
                             corr,
                             autojunk=False)
    
    rules = []
    
    if areta_tag == 'SPLIT': # Merge corruptions
        # we will just take the first token as a candidate to be merged with consecutive tokens
        words = orig.split(' ')
        rules.append({'pattern': (words[0]),
                      'rule': ('merge')})
    
    else:
        
        for tag, i1, i2, j1, j2 in sm.get_opcodes():
            i1_orig = i1
            i2_orig = i2

            if negative_indices:
                if i1 > (len(orig) + 1) // 2:
                    i1 = i1 - len(orig) - 1
                    i2 = i2 - len(orig) - 1

                if tag != 'equal':
                    
                    if tag == 'replace':
                        if i1 < 0:
                            rules.append({'pattern': (i1 + 1, None, orig[i1+1:]),
                                          'rule': (tag, corr[j1:j2])})
                        else:
                            rules.append({'pattern': (i1, i2, orig[i1:i2]),
                                          'rule': (tag, corr[j1:j2])})
            

                    elif tag == 'delete':
                        if 'INSERT' not in areta_tag:
                            
                            if i1 < 0:
                                rules.append({'pattern': (i1 + 1, None, orig[i1+1:]),
                                              'rule': (tag,'')})
                            else:
                                rules.append({'pattern': (i1, i2, orig[i1:i2]), 'rule': (tag, '')})
                        
                        else:
                            if i1 < 0:
                                rules.append({'pattern': (orig[i1+1:].strip(), ),
                                              'rule': (tag,'')})
                            else:
                                rules.append({'pattern': (orig[i1:i2].strip(), ), 'rule': (tag, '')})
                        

                    elif tag == 'insert':
                    
                        if 'DELETE' in areta_tag: # insert corruption

                            rules.append({'pattern': None, 'rule': (tag, corr[j1: j2])})

                        elif 'MERGE' in areta_tag: # split corruptions
                            if i1 < 0:
                                
                                rules.append({'pattern': (i1 + 1, None, orig[i1+1: ]),
                                              'rule': (tag, i1, corr[j1: j2])})

            
                            else:
                                
                                rules.append({'pattern': (None, i1, orig[0:i1]), 'rule': (tag, i1, corr[j1: j2])})
                        

                        
                        else:
#                             import pdb; pdb.set_trace()
                            tricky_set.add(areta_tag)
                            if i1 == 0 or i1 == -1:
                                rules.append({'pattern': (i1, None, orig[i1]), 'rule': (tag, i1, corr[j1: j2])})
                            else:
                                rules.append({'pattern': (i1 - 1, None, orig[i1 - 1]), 'rule': (tag, i1, corr[j1: j2])})

#     if 'INSERT' in areta_tag and 'INSERT_PM' not in areta_tag: 
#         import pdb; pdb.set_trace()

    return rules

# %%
data = load_data('/scratch/ba63/gec/data/alignment/modeling_areta_tags_check/'\
                'qalb14/qalb14_train.areta+.txt')

# %%
model = CorruptFactory.build(data)
len(model)
# Out:
# 7182

# %%
types = set([x[1] for x in list(model.model.keys())])
types
# Out:
# {'DELETE',
#  'INSERT_PM',
#  'INSERT_PM^*',
#  'INSERT_PM^2',
#  'INSERT_XM',
#  'INSERT_XM^*',
#  'INSERT_XM^2',
#  'MERGE',
#  'REPLACE_M',
#  'REPLACE_MI',
#  'REPLACE_MT',
#  'REPLACE_O',
#  'REPLACE_OA',
#  'REPLACE_OC',
#  'REPLACE_OD',
#  'REPLACE_OH',
#  'REPLACE_OM',
#  'REPLACE_OR',
#  'REPLACE_OT',
#  'REPLACE_OW',
#  'REPLACE_PC',
#  'REPLACE_PM',
#  'REPLACE_PT',
#  'REPLACE_S',
#  'REPLACE_SF',
#  'REPLACE_SW',
#  'REPLACE_X',
#  'REPLACE_XC',
#  'REPLACE_XF',
#  'REPLACE_XG',
#  'REPLACE_XM',
#  'REPLACE_XN',
#  'REPLACE_XT',
#  'SPLIT'}

# %%
model.examples[ ((1, 2, 'ل'), 'REPLACE_XM')]
# Out:
# defaultdict(<function __main__.CorruptFactory.build.<locals>.<lambda>.<locals>.<lambda>()>,
#             {('delete', ''): [{'src': 'فلماذا', 'tgt': 'فماذا'},
#               {'src': 'ولتداول', 'tgt': 'وتداول'},
#               {'src': 'فلتنتظر', 'tgt': 'فتنتظر'},
#               {'src': 'ولكن', 'tgt': 'وكن'},
#               {'src': 'ولنفس', 'tgt': 'ونفس'},
#               {'src': 'وليدافعوا', 'tgt': 'ويدافعون'},
#               {'src': 'وليغيروا', 'tgt': 'ويغيروا'}],
#              ('replace', 'ا'): [{'src': 'وللمصريين', 'tgt': 'والمصريين'},
#               {'src': 'وللجنوبيين', 'tgt': 'والجنوبيين'}]})

# %%
model[(('من',), 'INSERT_XM')]
# Out:
# {('delete', ''): 1.0}

# %%
for key in model.model.keys():
    if 'INSERT_XM' in key:
        print(f'Pattern {key}')
        for op in model[key]:
            print(f'Operation: {op}')
        print()
# Out:
# Pattern (('من',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('هناك',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الإرهابيون',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('القرن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('في',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بين',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('هذا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('سنوات',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('منه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('هل',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بشار',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بها',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('إما',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('على',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ليس',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الذي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أردوغان',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الصمت',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الله',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أناس',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('كان',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الفعل',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يقضي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('إلا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يمتلك',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('لا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أنتم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ش',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بنكيران',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وشكرا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('قد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أصبحت',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('هذه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تعبدون',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('شيئ',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الباطل',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بمشاركة',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('جدا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وأذلوهم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('عن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('مأجورين',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أنه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أموات',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وإن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أخي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('إنشق',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الذين',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بتدمير',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ظلت',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('كأنهما',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الماء',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('كادت',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('واحد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('قول',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وسيسقط',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('رصيد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('غزي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('إلخ',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('إليه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وجب',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أدى',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('و',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('غدا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ههه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('فيه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بحقد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ودعمتم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('هو',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ما',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('لي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('لنا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('والسلام',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أين',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('اهتمام',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تحت',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الشعب',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تخنق',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('شكرا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يفعل',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('شخصا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('سلام',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('للأسف',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('واحدا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('إنهم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الناس',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تريد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('قادها',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('والدول',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ادعاءهم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('السجون',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ماذا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('رئيسا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بليز',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('جاء',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أيها',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('عليه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('السعودية',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بدأ',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ورثه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أمين',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ثانيا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الحكم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تأثر',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('مالا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ليست',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يعيش',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الجهاد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('مليء',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('90',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وروسيا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الآن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('لأن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أو',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ألا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('التي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('سورية',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أنك',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يستطع',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أمة',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بسرعة',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تكن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تحمل',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('له',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('صغيرة',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('كبيرة',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('منها',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أسقطه',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('هيام',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('عندكم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('إنني',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وداعا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('به',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وهذا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('كل',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('صمدت',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('حال',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أمريكا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('كفاية',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('السيناريو',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('لهم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('لكن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('فهي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الدار',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تجرأ',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('المسلمون',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('لله',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ربما',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('موجود',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('حدث',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('إلى',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('عندها',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أنهم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('فوبيا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('كما',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وغما',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وأنا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يدعون',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ظن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الحمد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أحد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ستكون',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('سوف',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('هي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('عليها',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('منهم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وهي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يسكنون',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الفرنكوفونية',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('شهادة',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('والحصول',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('تأتي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('بنفسك',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('فقط',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('كذلك',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الإنسان',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('جميع',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('يشفق',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أبي',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('رغم',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ذكر',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الأزواد',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وسجن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وذبح',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('ير',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('وانتهينا',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('أسمع',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('نحن',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('التشيع',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('الحرب',), 'INSERT_XM')
# Operation: ('delete', '')
#
# Pattern (('القبض',), 'INSERT_XM')
# Operation: ('delete', '')

# %%
bla = 0
for key in model.model.keys():
    if model.counts[key] < 3:

# %%
bla
# Out:
# 9557

# %%
def create_rule(orig, corr, negative_indices=True):
    sm = difflib.SequenceMatcher(None,
                             orig,
                             corr,
                             autojunk=False)
    
    for tag, i1, i2, j1, j2 in sm.get_opcodes():
        i1_orig = i1
        i2_orig = i2

        if negative_indices:
            if i1 >= (len(orig) + 1) // 2:
                i1 = i1 - len(orig) - 1
                i2 = i2 - len(orig) - 1

            if tag == 'replace':
                print(f'Applicable: {[i1, i2, orig[i1:i2]]}')
                print([tag, i1, i2, corr[j1:j2]])
            
            elif tag == 'insert':
                print([tag, i1, corr[j1:j2]])
            
            elif tag == 'delete':
                print([tag, i1, i2])

# %%
create_rule('إلى', 
           'الى')
# Out:
# Applicable: [0, 1, 'إ']
# ['replace', 0, 1, 'ا']

# %%
'الصينية .'
