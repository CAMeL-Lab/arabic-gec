# %%
import rules
import json
from collections import Counter

# %%
def break_rule(rule):
    """Breaks multi-edit rule into muliple rules"""
    res = []
    for edit in rule.edits:
        edit = json.dumps(edit, ensure_ascii=False, sort_keys=True, indent=None)
        res.append(f'["CharEditScriptRule", {{"edits": [{edit}]}}, {{}}]')
    return res

# %%
def get_stats(rules):
    print(f'There are {len(rules)} in total')
    single_rules = []
    single_rules_str = []
    multi_rules = []
    broken_rules = []
    
    # get the single edit and multi edit rules
    for rule in rules:
        if len(rule.edits) <= 1: 
            single_rules.append(rule)
            single_rules_str.append(rule.to_str())
        else: # get the mutli
            multi_rules.append(rule)
            broken_rules.extend(break_rule(rule))

    assert len(single_rules) == len(set(single_rules))
    assert len(multi_rules) == len(set(multi_rules))
    
    print(f'There are {len(single_rules)} single rules')
    print(f'There are {len(multi_rules)} multi rules')
    print('----------------------')
    
    print(f'Breaking multi rules resulted in {len(broken_rules)} rules ({len(set(broken_rules))} types)')
    
    
    broken_oov = [rule for rule in broken_rules if rule not in single_rules_str]
    broken_in = [rule for rule in broken_rules if rule in single_rules_str]
    
    print(f'Out of the rules we broke, {len(broken_oov)} ({len(set(broken_oov))} types)'
          f' did not appear as single rules')
    print(f'Out of the rules we broke, {len(broken_in)} ({len(set(broken_in))} types)'
          f' appear as single rules')
    
    # Out of the rules we broke, we should discard the ones we've already seen
    # and keep the ones we haven't seen.
    
    pruned_rules = single_rules_str + list(set(broken_oov))
    print(f'We have {len(pruned_rules)} single rules after pruning')
    for x in pruned_rules:
        print(x)

# %%
# Load the rules
rules_list = []
with open('/scratch/ba63/gec/rule-based-data/MIX/3/RULES.LIST', "r", encoding="utf-8") as rules_file:
    for line in rules_file:
        line = line.rstrip("\n")
        rules_list.append(rules.Rule.from_str(line))

# %%
get_stats(rules_list)
# Out:
# There are 2647 in total
# There are 1169 single rules
# There are 1478 multi rules
# ----------------------
# Breaking multi rules resulted in 3055 rules (427 types)
# Out of the rules we broke, 195 (104 types) did not appear as single rules
# Out of the rules we broke, 2860 (323 types) appear as single rules
# We have 1273 single rules after pruning
# ["CharEditScriptRule", {"edits": []}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "[UNCORRECTABLE_ERROR]"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -4, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -4, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -4, -3]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -5, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -5, -4]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -7, -6]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 3]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 4]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 5]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 6]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 4]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 3]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 4]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 5]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 6]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 3, 4]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 3, 7]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 3, 8]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 4, 9]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 5, 6]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 6, 7]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ! "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " %"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ("]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ) ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ) ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ,"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " - ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " - :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " . "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " . -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " . . ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " . \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " : "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " : \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " \" ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " \" ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " }"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ، \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ؛ "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ؟ "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ؟ ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ؟ \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " إلى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " بها"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " على"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " عن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " في"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " كان"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " كنت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ما"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " من"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " هو"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " هي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ء ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ا !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ا )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ا ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ا :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ا ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ات"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ان"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ة "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ة أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "م ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ن "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ن ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "نا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ها"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "هم"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "وا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ون"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ى "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ي ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ي ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "يا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ية"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ين"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "يين"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " . "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " : "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " ، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, ","]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ء "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ام"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "خ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "دن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ش"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ص"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ــ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "لأ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "لا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "لى "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ن "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ون"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ي "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, ","]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "آل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ؤلاء "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ذا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ذه "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "لأ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "لإ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "لى "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ن "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ي "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -5, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ("]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ) ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ,"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " - ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " - ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " . "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " . -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " . . ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " . \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " : \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ["]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " \" ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " \" ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " } ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ، -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ، \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ، ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛ "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟ "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟ ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " أنه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " إلى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " الذي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " الله"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " على"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " عليه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " عن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " في"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " لا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ما"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " من"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " هذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " هذه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " هو"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " هي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "- "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "\" "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "{ "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ء "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ء ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ء ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ئا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ئا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ات"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ام"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ان"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ة ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "خ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "رة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "رى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ـ "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ل ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "لا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "لى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "م ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ما"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ن ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ن ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "نا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "نه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ني"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ه ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ه ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ها ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ها"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "هم"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "وا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ون"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ي ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ي ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "يا صديقي "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ية"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "يح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ين"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, " . "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, " ، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, ". أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, ". ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, ": ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ء "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "بال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "من ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ن "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ذا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ذه "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "لأ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "لإ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "لى "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ن "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ي "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 3, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 4, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " ، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "!"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "%"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "("]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, ") ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, ")"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, ","]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "-"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, ". "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "/"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, ":"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "?"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "\" ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "\""]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "{"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "} ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "}"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "، آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "، إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "، ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "، و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "، ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ء ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ءا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "أ ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "أو"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ؤا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "إي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ئا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ئا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ئو"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ا ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ا ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ا ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "اء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ائ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "اة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ات"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "اه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة ,"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ت ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ته"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "تي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "خ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ذ ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ذه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ذي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ذين"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ز"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ش"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ص"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ع ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "غ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "في"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "لأ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "لإ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "لى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "م ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "م ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ما"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ن "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ن ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ن ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ن ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "نا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "نه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ني"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ه "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ه ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ه ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ه ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "هم"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "وء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "وا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ون"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ى -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ى ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ى :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ى ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ى ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "يء ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "يء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "يء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "يا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ية"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "يت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ين"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "يه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, " ذلك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "أة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "أذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "أط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "أي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "إذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ئذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "تي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ذه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ذي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ذين"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ماذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "أر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "أو"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "أي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "إي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "اء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ائ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "خ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ز"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ش"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ص"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "غ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "لأ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -1, "حق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, " إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "إل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "خ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -5, -4, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -6, -5, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " . أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " . إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " ، أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " ؟ أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, " ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "\" أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "\" إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ءا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "إن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "اء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ة "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "خ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ز"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ص"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "غ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "م "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "يي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "أو"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "تش"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "ز"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 4, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, " إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "! أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "! إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "( أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "( إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, ", أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, ", إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "- أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "- إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, ". "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, ". آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, ". أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, ". إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, ". ا"]]}, {}]
# ...
# ["CharEditScriptRule", {"edits": [["replace_all", "أت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "أك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "أو"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "أي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "أيي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ؤا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "إلى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ئ "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ئ ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ئا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ئة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ئو"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ئي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ا ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ا أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "اء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "اء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "اؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ائ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ات"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ادة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "الله"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "اه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة أي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ت ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "تا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ته"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "تي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ثل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "خ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "دئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "دد"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ذلك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ذه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ذي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "راة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "رة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "رى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ز"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "زي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "س ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ش"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "شاهد"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "شكرا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ص"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ضع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ط ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ظهر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "عل ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "عل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "غ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "كم"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "كي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "لأجل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "لا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "لة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "لك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "لى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "م "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "م ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "م ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "م ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ما"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ماذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ن ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "نا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "نه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ني"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه ، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ها"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "هذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "هم ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "هم"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "وء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "وء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "وا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ون ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ون"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ى ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي أي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يء ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يئا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ية ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ية"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يس"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يكفي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "ين"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace_all", "يي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "إلى "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ان"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, ":"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ذا ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "يونية"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -5, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -5, -4, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "الذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "يء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, ": إذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ى "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ي ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ما"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, "ئي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ة ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -2, -1, " أنت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 3, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "اء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "إن ش"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "إن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "إن ش"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ف"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، إن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -3, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, ". أم"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، إذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, ". ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "إل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "اء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "إذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -2, "هذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "آل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ناك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ذي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 3, "أيض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "يي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "وجد"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ى ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "أم"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, ". إذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "، ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -6, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "أي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 0, 1, "."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 3, "هؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "أنه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " غير"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "إن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " ؛ "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "أخ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "إن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ى ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "أر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, ". إن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 3, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 2, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ى "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "أر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "إد"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "الت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -4, -2, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", -3, -1, "ء "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "إذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -5, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ذا ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "، أل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ع"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, "ذا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "أب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 1, "؟ إلى هذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -1, " آل"]]}, {}]

# %%
1169 + 104
# Out:
# 1273

# %%
x = break_rule(single_rules[0])

# %%
rules.Rule.from_str(x[0])

# %%
single_rules[0].to_str()
# Out:
# '["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, " ،"]]}, {}]'

# %%
for x in x_rules:
    print(x.to_str())
# Out:
# ["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, "ذا ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, "ذا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -3, -2], ["insert", -1, "ذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -4, -3], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -4, -3], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -4, -3], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", -4, -3], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["delete", 2, 3], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["delete", 2, 3]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["delete", 2, 5]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " ,"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, " ـ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "نا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "وا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ون"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -2, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -3, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["insert", -4, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "آ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "ض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -3, -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -4, -3, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -4, -3, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -4, -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -4, -3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", -4, -3, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 2, 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 2, 3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 2, 4, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 3, 4, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 3, 4, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 3, 4, "إ"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 3, 4, "إ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 3, 4, "إ"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 3, 4, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 1], ["replace", 3, 4, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, " !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, " \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, "وا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -2, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -3, -2, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -3, -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -3, -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", -4, -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", 3, 4, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 2], ["replace", 3, 4, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 3], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 3], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 0, 3], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["delete", -4, -3]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, " ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, "ذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, "نا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -1, "وجد"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["insert", -2, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", -2, -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", -3, -2, "لأ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", -4, -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 2], ["replace", 3, 4, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, " ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, " ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, "ناك"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 1, 3], ["insert", -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 3], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 3], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 3], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 3], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 3], ["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["delete", 2, 3], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " "], ["insert", -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " "], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, " ؛ "], ["insert", -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ا"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ا"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ا"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ا"], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ذ"], ["insert", -1, " ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ذ"], ["insert", -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ل"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ل"], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ن"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ن"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "و"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ي"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ي"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ي"], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ي"], ["insert", -1, "ا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ي"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -2, "ي"], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " "], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " "], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " "], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " "], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " "], ["insert", -2, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, " أ"], ["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "آل"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "أر"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ئ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ا"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ا"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ا"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ا"], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ا"], ["replace", -2, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ب"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ت"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ح"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "د"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ذ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ر"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "س"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ع"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ف"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ق"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ك"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ل"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ل"], ["replace", -2, -1, "ان"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "م"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ن"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ه"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ي"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -3, "ي"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, " "], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, " "], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, " "], ["insert", -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "آل"], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ا"], ["replace", -3, -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ر"], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ع"], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -4, "ي"], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -5, " "], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -5, " "], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -5, "ر"], ["delete", -4, -3]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -5, "ي"], ["delete", -4, -3]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", -6, "ر"], ["delete", -5, -4]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " !"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " !"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " !"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " !"], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " !"], ["replace", 2, 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -2, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", -3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", 1, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", 1, " "], ["insert", -2, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", 1, " "], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", 1, " "], ["insert", -3, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["insert", 1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -2, -1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -2, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -2, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", 1, 2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " "], ["replace", 1, 2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ("], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ("], ["insert", -1, " )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ("], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ("], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ,"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ,"], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -1, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -4, " "], ["insert", -1, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["insert", -4, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", -2, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", -2, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", 2, 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", 2, 3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " -"], ["replace", 3, 4, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " . "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " . "], ["replace", 1, 2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["delete", 2, 3]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, " أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, " ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, " ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -3, " "], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -3, " "], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -3, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -3, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -3, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -4, " "], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", -4, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", 2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", 2, "إن ش"], ["replace", -3, -1, "ء "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", 2, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["insert", 3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -3, -2, "آ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -3, -2, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -3, -2, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -3, -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -3, -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -3, -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -4, -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", -4, -3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", 2, 3, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", 2, 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", 2, 3, "إ"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", 2, 3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", 3, 4, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ."], ["replace", 3, 4, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["insert", -1, " ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["insert", -3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["insert", 3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["replace", -3, -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["replace", -4, -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["replace", 2, 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " :"], ["replace", 3, 4, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " \""], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " \""], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " \""], ["insert", -1, " \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " \""], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ، "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ، "], ["replace", 1, 2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ، "], ["replace", 1, 2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["delete", -3, -2], ["insert", -1, "ذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["delete", -4, -3]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["delete", 2, 3]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["delete", 2, 4]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["delete", 2, 5]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " آل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, " ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "د"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ر"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ض"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ط"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ما"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "وا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "ا "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "إن"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "ا"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "ذ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -3, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -4, " "], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -4, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", -5, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", 2, "إن ش"], ["replace", -3, -1, "ء "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", 2, "ا"], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", 2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", 2, "ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", 2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["insert", 3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ح"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ز"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "س"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ق"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ي ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -1, "أذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -1, "إذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -1, "ماذا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "آ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ذ"], ["insert", -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "هذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -3, -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -4, -3, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -4, -3, "أ"], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -4, -3, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -4, -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -4, -3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -4, -3, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", -4, -3, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "أ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "أ"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "أ"], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "إ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "إ"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "إ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "إ"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "إ"], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 2, 3, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 3, 4, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 3, 4, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 3, 4, "إ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 3, 4, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 4, 5, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 4, 5, "إ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ،"], ["replace", 4, 5, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛ "], ["replace", 1, 2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["insert", -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["insert", -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["insert", -3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", -2, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", -3, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", -3, -2, "أ"], ["insert", -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", -3, -2, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", 2, 3, "أ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", 2, 3, "أ"], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", 2, 3, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؛"], ["replace", 2, 3, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟ "], ["replace", 1, 2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟"], ["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟"], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["insert", 0, " ؟"], ["insert", -1, " :"]]}, {}]
# ...
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", -2, " ل"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", -3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", -3, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", 3, "ر"], ["delete", -4, -3], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["insert", 3, "ر"], ["delete", -4, -3]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ئ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ئي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ب"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ه"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ى ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ي "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -3, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -3, -2, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -3, -2, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -3, -2, "ظ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "أ"], ["replace", -3, -2, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ؤ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["delete", -4, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " ,"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, " أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, "ء"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, "ا ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -2, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -3, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -4, " "], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["insert", -4, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["replace", -2, -1, "أ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["replace", -2, -1, "ؤ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["replace", -2, -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["replace", -2, -1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["replace", -2, -1, "ن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "إ"], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ئ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ا"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ا"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ا"], ["insert", -1, "ت"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ا"], ["insert", -1, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ا"], ["insert", -2, "ذ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ا"], ["replace", -2, -1, "آ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ا"], ["replace", -2, -1, "إ"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ا"], ["replace", -2, -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ب"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ت"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ت"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ج"], ["replace", -3, -2, "ج"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ذ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ف"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "في "], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ل"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ل"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ن"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ن"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "و"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "و"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "و"], ["insert", -1, " ال"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "و"], ["insert", -1, "نا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ي"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ي"], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ي"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ي"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ي"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ي"], ["insert", -1, "وا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "ي"], ["insert", -1, "ون"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 2, "يري"], ["replace", -2, -1, " أن"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 3, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 3, "أيض"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 3, "ب"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 1, 3, "هؤ"], ["insert", -1, "اء ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "آ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["insert", -1, "م"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["replace", -2, -1, "ث"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "أ"], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "إ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "إ"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "إ"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "إ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "إ"], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "إ"], ["insert", -2, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "إ"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "ث"], ["insert", -1, "ا"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "ث"], ["insert", -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 2, 3, "ن"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "آ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "آ"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "آ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "آ"], ["insert", -1, " ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "آ"], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "آ"], ["replace", -2, -1, "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "آ"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["delete", -3, -2]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " ,"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " . "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " ، "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, "ة "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -3, "ر"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["insert", -6, "ر"], ["delete", -5, -4]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["replace", -2, -1, "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["replace", -2, -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["replace", -2, -1, "ى ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "أ"], ["replace", -2, -1, "ى"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["delete", -2, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["delete", -3, -1]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " !"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " "]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " )"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " -"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " :"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " \""]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " ؛"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, " ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["insert", -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["replace", -2, -1, "ة ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["replace", -2, -1, "ة ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["replace", -2, -1, "ة ؟"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["replace", -2, -1, "ة"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["replace", -2, -1, "ي"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "إ"], ["replace", -3, -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "ئ"], ["replace", -3, -2, "و"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "ا"], ["insert", -1, " ,"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "ا"], ["insert", -1, " ."]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 3, 4, "ا"], ["insert", -1, " ،"]]}, {}]
# ["CharEditScriptRule", {"edits": [["replace", 4, 5, "إ"], ["insert", -1, " ،"]]}, {}]
